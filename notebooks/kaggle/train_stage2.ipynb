# %% [markdown]
# # DamageNet - Train Stage 2

# %%
# !git clone https://github.com/MSK-005/damagenet.git
# %cd damagenet
# !pip install -r requirements.txt -q
# !pip install -e . -q

# %%
import os
from kaggle_secrets import UserSecretsClient
os.environ['WANDB_API_KEY'] = UserSecretsClient().get_secret('WANDB_API_KEY')

# %%
# If loading Stage 1 checkpoint from a Kaggle dataset (cross-session).
# attach it via Add Data and update kaggle.stage1_input_path in configs/model.yaml.
# If running Stage 1 and Stage 2 in the same session, skip this.
# !python src/train_stage2.py

# %%
# !python src/convert_to_onnx.py
